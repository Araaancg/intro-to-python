# %% [markdown]
# # Tema 10: Ficheros en Python
# ---
#
# Los ficheros nos permiten **guardar información de forma permanente** en el disco duro. Sin ficheros, todos los datos de nuestro programa se pierden al cerrarlo.

# %% [markdown]
# ## 1. ¿Por qué necesitamos ficheros?
#
# Imagina que tienes un programa de gestión de notas de estudiantes:
#
# - **Sin ficheros**: Cada vez que cierras el programa, pierdes todas las notas. Tendrías que volver a introducirlas.
# - **Con ficheros**: Las notas se guardan en un archivo. La próxima vez que abres el programa, las recuperas.
#
# ### Entrada y salida de datos
#
# | Sin ficheros | Con ficheros |
# |--------------|-------------|
# | Entrada: teclado (`input()`) | Entrada: leer fichero |
# | Salida: pantalla (`print()`) | Salida: escribir fichero |

# %% [markdown]
# ## 2. Tipos de ficheros de texto
#
# Nos vamos a centrar en tres formatos muy utilizados:
#
# | Formato | Extensión | Uso típico | Ejemplo |
# |---------|-----------|------------|--------|
# | **Texto plano** | `.txt` | Notas, logs, texto libre | `notas.txt` |
# | **CSV** | `.csv` | Datos tabulares (como Excel) | `alumnos.csv` |
# | **JSON** | `.json` | Configuraciones, APIs, datos estructurados | `config.json` |

# %% [markdown]
# ### 2.1 Ficheros de texto plano (.txt)
#
# El formato más simple. Cada línea es texto libre.
#
# ```
# Esto es la primera línea
# Esto es la segunda línea
# Y esto la tercera
# ```

# %% [markdown]
# ### 2.2 Ficheros CSV (.csv) - Comma Separated Values
#
# Datos separados por comas (o punto y coma). Muy usado para datos tabulares.
#
# ```
# nombre,edad,ciudad
# Ana,22,Madrid
# Luis,19,Barcelona
# María,21,Valencia
# ```
#
# 💡 Es el formato que usa Excel para importar/exportar datos.

# %% [markdown]
# ### 2.3 Ficheros JSON (.json) - JavaScript Object Notation
#
# Formato estructurado muy usado en APIs y configuraciones. Se parece mucho a los diccionarios de Python.
#
# ```json
# {
#     "nombre": "Ana",
#     "edad": 22,
#     "ciudad": "Madrid",
#     "notas": [8.5, 9.0, 7.5]
# }
# ```
#
# 💡 Es el formato estándar para intercambiar datos en la web.

# %% [markdown]
# ---
#
# ## 3. Operaciones básicas con ficheros
#
# Todos los ficheros siguen el mismo patrón:
#
# 1. **Abrir** el fichero
# 2. **Leer** o **escribir**
# 3. **Cerrar** el fichero
#
# ### Modos de apertura
#
# | Modo | Descripción | Si el fichero existe | Si NO existe |
# |------|-------------|---------------------|---------------|
# | `"r"` | Lectura (read) | Lo abre | ❌ Error |
# | `"w"` | Escritura (write) | ⚠️ Lo BORRA y crea nuevo | Lo crea |
# | `"a"` | Añadir (append) | Añade al final | Lo crea |

# %% [markdown]
# ---
#
# ## 4. Ficheros de texto plano (.txt)
#
# ### 4.1 Escribir en un fichero

# %%
# Forma básica: abrir, escribir, cerrar
fichero = open("mi_fichero.txt", "w")
fichero.write("Hola mundo\n")
fichero.write("Esta es la segunda línea\n")
fichero.close()

# %%
# ✅ Forma recomendada: usar 'with' (cierra automáticamente)
with open("mi_fichero.txt", "w") as fichero:
    fichero.write("Hola mundo\n")
    fichero.write("Esta es la segunda línea\n")
    fichero.write("Y esta la tercera\n")
# Al salir del 'with', el fichero se cierra solo

# %% [markdown]
# ⚠️ **Importante**: `write()` NO añade salto de línea automáticamente. Tienes que poner `\n` tú.

# %% [markdown]
# ### 4.2 Leer un fichero

# %%
# Método 1: read() - Lee TODO el fichero como un string
with open("mi_fichero.txt", "r") as fichero:
    contenido = fichero.read()
    print(contenido)
    print(f"Tipo: {type(contenido)}")
# Out:
# Hola mundo
# Esta es la segunda línea
#
# Tipo: <class 'str'>

# %%
# Método 2: readlines() - Lee todas las líneas en una LISTA
with open("mi_fichero.txt", "r") as fichero:
    lineas = fichero.readlines()
    print(lineas)
    print(f"Tipo: {type(lineas)}")
    print(f"Número de líneas: {len(lineas)}")
# Out:
# ['Hola mundo\n', 'Esta es la segunda línea\n']
# Tipo: <class 'list'>
# Número de líneas: 2

# %%
# Método 3: Iterar línea a línea (más eficiente para ficheros grandes)
with open("mi_fichero.txt", "r") as fichero:
    for linea in fichero:
        print(f"Línea: {linea.rstrip()}")  # rstrip() quita el \n del final
# Out:
# Línea: Hola mundo
# Línea: Esta es la segunda línea

# %% [markdown]
# ### 4.3 Añadir contenido (append)

# %%
# Modo "a" - Añade al final SIN borrar lo anterior
with open("mi_fichero.txt", "a") as fichero:
    fichero.write("Esta línea se añade al final\n")

# Comprobamos
with open("mi_fichero.txt", "r") as fichero:
    print(fichero.read())
# Out:
# Hola mundo
# Esta es la segunda línea
# Esta línea se añade al final

# %% [markdown]
# ### 4.4 Escribir una lista de líneas

# %%
# writelines() escribe una lista de strings
lineas = ["Primera", "Segunda\n", "Tercera\n"]

with open("lista_lineas.txt", "w") as fichero:
    fichero.writelines(lineas)

# Verificamos
with open("lista_lineas.txt", "r") as fichero:
    print(fichero.read())
# Out:
# PrimeraSegunda
# Tercera

# %% [markdown]
# ---
#
# ## 5. Ficheros CSV
#
# Python tiene un módulo `csv` que facilita trabajar con este formato.
#
# ### 5.1 Escribir un CSV

# %%
from csv import writer

# Datos a guardar
alumnos = [
    ["nombre", "edad", "nota"],  # Cabecera
    ["Ana", 22, 8.5],
    ["Luis", 19, 7.0],
    ["María", 21, 9.2]
]

with open("alumnos.csv", "w", newline="") as fichero:
    escritor = writer(fichero)
    for fila in alumnos:
        escritor.writerow(fila)

print("Fichero CSV creado!")
# Out:
# Fichero CSV creado!

# %%
# Veamos cómo quedó el fichero
with open("alumnos.csv", "r") as fichero:
    print(fichero.read())
# Out:
# nombre,edad,nota
# Ana,22,8.5
# Luis,19,7.0
# María,21,9.2

# %% [markdown]
# ### 5.2 Leer un CSV

# %%
import csv

with open("alumnos.csv", "r") as fichero:
    lector = csv.reader(fichero)
    for fila in lector:
        print(fila)  # Cada fila es una lista
# Out:
# ['nombre', 'edad', 'nota']
# ['Ana', '22', '8.5']
# ['Luis', '19', '7.0']
# ['María', '21', '9.2']

# %%
# Separar cabecera de datos
import csv

with open("alumnos.csv", "r") as fichero:
    lector = csv.reader(fichero)
    cabecera = next(lector)  # Lee la primera fila
    print(f"Columnas: {cabecera}")
    print("---")
    for fila in lector:
        nombre, edad, nota = fila
        print(fila)
# Out:
# Columnas: ['nombre', 'edad', 'nota']
# ---
# ['Ana', '22', '8.5']
# ['Luis', '19', '7.0']
# ['María', '21', '9.2']

# %% [markdown]
# ### 5.3 CSV con diccionarios (más cómodo)

# %%
import csv

# Escribir CSV desde lista de diccionarios
alumnos = [
    {"nombre": "Ana", "edad": 22, "nota": 8.5},
    {"edad": 19, "nota": 7.0, "nombre": "Luis"},
    {"nombre": "María", "edad": 21, "nota": 9.2}
]

with open("alumnos_dict.csv", "w", newline="") as fichero:
    campos = ["nombre", "edad", "nota"]
    escritor = csv.DictWriter(fichero, fieldnames=campos)
    
    escritor.writeheader()  # Escribe la cabecera
    for alumno in alumnos:
        escritor.writerow(alumno)

print("CSV con diccionarios creado!")
# Out:
# CSV con diccionarios creado!

# %%
import csv

# Leer CSV como diccionarios
with open("alumnos_dict.csv", "r") as fichero:
    lector = csv.DictReader(fichero)
    for fila in lector:
        print(fila)  # Cada fila es un diccionario
        # print(f"  -> {fila['nombre']} sacó un {fila['nota']}")
# Out:
# {'nombre': 'Ana', 'edad': '22', 'nota': '8.5'}
# {'nombre': 'Luis', 'edad': '19', 'nota': '7.0'}
# {'nombre': 'María', 'edad': '21', 'nota': '9.2'}

# %% [markdown]
# ### 5.4 CSV con punto y coma (común en España)

# %%
import csv

# En España es común usar ; como separador (por la coma decimal)
alumnos = [
    ["nombre", "nota"],
    ["Ana", "8,5"],  # Nota con coma decimal española
    ["Luis", "7,0"]
]

with open("alumnos_esp.csv", "w", newline="") as fichero:
    escritor = csv.writer(fichero, delimiter=";")  # Cambiamos el separador
    for fila in alumnos:
        escritor.writerow(fila)

# Verificamos
with open("alumnos_esp.csv", "r") as fichero:
    print(fichero.read())

# %%
# Para leerlo, también especificamos el delimitador
import csv

with open("alumnos_esp.csv", "r") as fichero:
    lector = csv.reader(fichero, delimiter=";")
    for fila in lector:
        print(fila)

# %% [markdown]
# ---
#
# ## 6. Ficheros JSON
#
# Python tiene un módulo `json` para trabajar con este formato.
#
# ### 6.1 Escribir JSON

# %%
import json

# Un diccionario de Python se convierte fácilmente a JSON
alumno = {
    "nombre": "Ana García",
    "edad": 22,
    "carrera": "Ingeniería",
    "notas": [8.5, 9.0, 7.5, 8.0],
    "activo": True
}

with open("alumno.json", "w") as fichero:
    json.dump(alumno, fichero)

print("JSON creado!")
# Out:
# JSON creado!

# %%
# Veamos cómo quedó
with open("alumno.json", "r") as fichero:
    print(fichero.read())

# %%
# Para que quede más bonito (indentado)
import json

with open("alumno_bonito.json", "w") as fichero:
    json.dump(alumno, fichero, indent=4)  # indent=4 espacios

with open("alumno_bonito.json", "r") as fichero:
    print(fichero.read())
# Out:
# {
#     "nombre": "Ana Garc\u00eda",
#     "edad": 22,
#     "carrera": "Ingenier\u00eda",
#     "notas": [
#         8.5,
#         9.0,
#         7.5,
#         8.0
#     ],
#     "activo": true
# }

# %% [markdown]
# ### 6.2 Leer JSON

# %%
import json

with open("alumno.json", "r") as fichero:
    datos = json.load(fichero)

print(f"Tipo: {type(datos)}")
print(f"Nombre: {datos['nombre']}")
print(f"Notas: {datos['notas']}")
print(f"Media: {sum(datos['notas']) / len(datos['notas']):.2f}")
# Out:
# Tipo: <class 'dict'>
# Nombre: Ana García
# Notas: [8.5, 9.0, 7.5, 8.0]
# Media: 8.25

# %% [markdown]
# ### 6.3 JSON con lista de objetos

# %%
import json

# Lista de alumnos (muy común en APIs)
alumnos = [
    {"nombre": "Ana", "edad": 22, "nota": 8.5},
    {"nombre": "Luis", "edad": 19, "nota": 7.0},
    {"nombre": "María", "edad": 21, "nota": 9.2}
]

with open("alumnos.json", "w") as fichero:
    json.dump(alumnos, fichero, indent=2)

# Verificamos
with open("alumnos.json", "r") as fichero:
    print(fichero.read())
# Out:
# [
#   {
#     "nombre": "Ana",
#     "edad": 22,
#     "nota": 8.5
#   },
#   {
#     "nombre": "Luis",
#     "edad": 19,
#     "nota": 7.0
#   },
#   {
#     "nombre": "Mar\u00eda",
#     "edad": 21,
#     "nota": 9.2
#   }
# ]

# %%
import json

# Leer y procesar
with open("alumnos.json", "r") as fichero:
    alumnos = json.load(fichero)

print(f"Hay {len(alumnos)} alumnos")
for alumno in alumnos:
    print(alumno)
    # print(f"- {alumno['nombre']}: {alumno['nota']}")
# Out:
# Hay 3 alumnos
# {'nombre': 'Ana', 'edad': 22, 'nota': 8.5}
# {'nombre': 'Luis', 'edad': 19, 'nota': 7.0}
# {'nombre': 'María', 'edad': 21, 'nota': 9.2}

# %% [markdown]
# ### 6.4 Convertir entre string y JSON

# %%
import json

# Diccionario a string JSON (sin fichero)
datos = {"nombre": "Ana", "edad": 22}
json_string = json.dumps(datos)  # dumps = dump string
print(f"String JSON: {json_string}")
print(f"Tipo: {type(json_string)}")
# Out:
# String JSON: {"nombre": "Ana", "edad": 22}
# Tipo: <class 'str'>

# %%
import json

# String JSON a diccionario (sin fichero)
json_string = '{"nombre": "Luis", "edad": 25}'
datos = json.loads(json_string)  # loads = load string
print(f"Diccionario: {datos}")
print(f"Tipo: {type(datos)}")
# Out:
# Diccionario: {'nombre': 'Luis', 'edad': 25}
# Tipo: <class 'dict'>

# %% [markdown]
# ---
#
# ## 7. Comparativa: ¿Cuándo usar cada formato?
#
# | Formato | Ventajas | Desventajas | Usar cuando... |
# |---------|----------|-------------|----------------|
# | **TXT** | Simple, ligero | Sin estructura | Logs, notas, texto libre |
# | **CSV** | Compatible con Excel | Solo datos tabulares | Tablas de datos, exportar a Excel |
# | **JSON** | Datos complejos, estándar web | Más pesado | APIs, configuraciones, datos anidados |

# %% [markdown]
# ---
#
# ## 8. Gestión de errores con ficheros
#
# Es importante manejar errores, especialmente cuando el fichero puede no existir.

# %%
# Intentar leer un fichero que no existe
try:
    with open("mi_fichero.txt", "r") as fichero:
        contenido = fichero.read()
except FileNotFoundError:
    print("Error: El fichero no existe")
# Out:
# Finally

# %%
# Patrón completo de gestión de errores
import json

def cargar_configuracion(ruta: str) -> dict:
    """Carga configuración desde un fichero JSON
    
    Args:
        ruta: Ruta al fichero JSON
        
    Returns:
        Diccionario con la configuración, o dict vacío si hay error
    """
    try:
        with open(ruta, "r") as fichero:
            return json.load(fichero)
    except FileNotFoundError:
        print(f"Aviso: No se encontró {ruta}, usando configuración por defecto")
        return {}
    except json.JSONDecodeError:
        print(f"Error: El fichero {ruta} no es un JSON válido")
        return {}
    except:
        print("Ha pasado algo")

# Probar con fichero que no existe
config = cargar_configuracion("config.json")
print(f"Configuración: {config}")
# Out:
# Aviso: No se encontró config.json, usando configuración por defecto
# Configuración: {}

# %% [markdown]
# ---
#
# ## 9. Ejemplo práctico: Sistema de notas
#
# Vamos a crear un pequeño sistema que guarda y carga notas de alumnos.

# %%
import json

FICHERO_NOTAS = "notas_clase.json"

def cargar_notas() -> list:
    """Carga las notas desde el fichero JSON"""
    try:
        with open(FICHERO_NOTAS, "r") as fichero:
            return json.load(fichero)
    except FileNotFoundError:
        return []  # Si no existe, devolvemos lista vacía


def guardar_notas(notas: list) -> None:
    """Guarda las notas en el fichero JSON"""
    with open(FICHERO_NOTAS, "w") as fichero:
        json.dump(notas, fichero, indent=2)


def agregar_alumno(notas: list, nombre: str, nota: float) -> None:
    """Añade un nuevo alumno a la lista"""
    notas.append({"nombre": nombre, "nota": nota})
    guardar_notas(notas)
    print(f"Alumno {nombre} añadido con nota {nota}")


def mostrar_notas(notas: list) -> None:
    """Muestra todas las notas"""
    if not notas:
        print("No hay alumnos registrados")
        return
    
    print("\n=== LISTADO DE NOTAS ===")
    for alumno in notas:
        estado = "✓" if alumno["nota"] >= 5 else "✗"
        print(f"{estado} {alumno['nombre']}: {alumno['nota']}")
    
    # Calcular media
    media = sum(a["nota"] for a in notas) / len(notas)
    print(f"\nMedia de la clase: {media:.2f}")

# %%
# Programa principal
notas = cargar_notas()

# Añadir algunos alumnos
agregar_alumno(notas, "Ana", 8.5)
agregar_alumno(notas, "Luis", 4.5)
agregar_alumno(notas, "María", 9.0)

# Mostrar notas
mostrar_notas(notas)

# %%
# Verificamos que se guardó correctamente
with open(FICHERO_NOTAS, "r") as fichero:
    print(fichero.read())

# %% [markdown]
# ---
#
# ## 📝 Resumen
#
# ### Funciones principales
#
# | Formato | Escribir | Leer |
# |---------|----------|------|
# | **TXT** | `fichero.write(texto)` | `fichero.read()` / `fichero.readlines()` |
# | **CSV** | `csv.writer()` + `writerow()` | `csv.reader()` |
# | **JSON** | `json.dump(datos, fichero)` | `json.load(fichero)` |
#
# ### Buenas prácticas
#
# 1. **Siempre usar `with`** para abrir ficheros (se cierran automáticamente)
# 2. **Manejar errores** con `try/except`, especialmente `FileNotFoundError`
# 3. **Usar el formato adecuado**: TXT para texto, CSV para tablas, JSON para datos estructurados
# 4. **No olvidar `newline=""`** al escribir CSV en Windows
# 5. **Usar `indent`** en JSON para que sea legible
