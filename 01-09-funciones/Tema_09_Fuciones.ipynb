# %% [markdown]
# # Tema 9: Funciones en Python
# ---

# %% [markdown]
# ## 1. ¿Qué es una función?
#
# Una función es como una **receta de cocina**:
#
# 1. Le das unos **ingredientes** (parámetros de entrada)
# 2. La receta **hace algo** con ellos (instrucciones)
# 3. Te devuelve un **plato terminado** (resultado)
#
# Por ejemplo, imagina una función `hacer_tortilla`:
# - **Ingredientes**: huevos, patatas, sal
# - **Proceso**: batir, freír, dar la vuelta...
# - **Resultado**: una tortilla lista para comer
#
# En programación, una función es un **bloque de código independiente** que:
# - Tiene un **nombre único**
# - Recibe **parámetros** (opcionales)
# - Ejecuta unas **instrucciones**
# - Puede **devolver un resultado**

# %% [markdown]
# ## 2. Funciones integradas:

# %%
# print() - Muestra texto en pantalla
print("¡Hola! Soy una función que ya conocías")
# Out:
# ¡Hola! Soy una función que ya conocías

# %%
# type() - Te dice el tipo de un dato
type(42)
# Out:
# int

# %%
# len() - Cuenta elementos
len("Python")
# Out:
# 6

# %%
# int() - Convierte a entero
int("25")
# Out:
# 25

# %%
# input() - Pide datos al usuario
nombre = input("¿Cómo te llamas? ")
print(nombre)
# Out:
# ¿Cómo te llamas? Arancha
# Arancha

# %% [markdown]
# ### 💡 Patrón que todas las funciones tienen
#
# Todas las funciones siguen la misma estructura:
#
# ```python
# nombre_funcion(argumentos)
# ```
#
# Los paréntesis `()` son obligatorios, aunque no haya argumentos.

# %% [markdown]
# ## 3. Funciones que devuelven resultado vs las que no
#
# Hay dos tipos de funciones:
#
# ### Tipo A: Devuelven un resultado (puedes guardarlo en una variable)

# %%
# int() devuelve un número que podemos guardar
numero = int("25")
print(f"El número es: {numero}")
print(f"Su tipo es: {type(numero)}")
# Out:
# El número es: 25
# Su tipo es: <class 'int'>

# %%
# len() devuelve la longitud
longitud = len("Hola mundo")
print(f"La frase tiene {longitud} caracteres")

# %% [markdown]
# ### Tipo B: NO devuelven resultado (solo hacen una acción)

# %%
# print() NO devuelve nada, solo muestra en pantalla
resultado = print("Hola")
print(f"¿Qué devolvió print? {resultado}")
print(f"Su tipo es: {type(resultado)}")
# Out:
# Hola
# ¿Qué devolvió print? None
# Su tipo es: <class 'NoneType'>

# %%
# sort() ordena la lista pero NO devuelve nada
mi_lista = [3, 1, 4, 1, 5, 9, 2, 6]
resultado = mi_lista.sort()

print(f"La lista ordenada: {mi_lista}")
print(f"¿Qué devolvió sort()? {resultado}")
# Out:
# La lista ordenada: [1, 1, 2, 3, 4, 5, 6, 9]
# ¿Qué devolvió sort()? None

# %%
# append() añade un elemento pero NO devuelve nada
mi_lista = [1, 2, 3]
resultado = mi_lista.append(4)

print(f"La lista ahora: {mi_lista}")
print(f"¿Qué devolvió append()? {resultado}")
# Out:
# La lista ahora: [1, 2, 3, 4]
# ¿Qué devolvió append()? None

# %% [markdown]
# ---
#
# ## 4. Creando nuestras propias funciones
#
# Ahora viene lo interesante: **crear nuestras propias funciones**.
#
# ### La anatomía de una función
#
# ```python
# def nombre_funcion(parametro1, parametro2):
#     """Descripción de qué hace la función"""
#     # Instrucciones
#
#     return resultado
# ```
#
# - `def` → palabra reservada para **def**inir funciones
# - `nombre_funcion` → el nombre que le damos (debería ser un verbo: calcular, mostrar, obtener...)
# - `parametros` → los "ingredientes" que recibe
# - `return` → lo que devuelve (opcional)

# %%
def mayor_18(num):
  if num >= 18:
    return "si"
  else:
    return "no"

# %% [markdown]
# ### Tu primera función

# %%
# Definimos la función
def saludar(nombre):
    """Saluda a una persona por su nombre"""
    print(f"¡Hola, {nombre}!")

# %%
# Llamamos a la función
saludar("María")
# Out:
# '¡Hola, María!'

# %%
# Podemos llamarla muchas veces con diferentes argumentos
print(saludar("Carlos"))
print(saludar("Ana"))
print(saludar("Python"))
# Out:
# ¡Hola, Carlos!
# ¡Hola, Ana!
# ¡Hola, Python!

# %% [markdown]
# ### Ejemplo práctico: Calcular la hipotenusa
#
# Imagina que necesitas calcular la hipotenusa de varios triángulos.
#
# **Sin funciones** (código repetido):

# %%
import math

# Triángulo 1
cateto1a = 2
cateto1b = 3
hipotenusa1 = math.sqrt((cateto1a**2) + (cateto1b**2))
print(hipotenusa1)

# Triángulo 2
cateto2a = 4
cateto2b = 6
hipotenusa2 = math.sqrt((cateto2a**2) + (cateto2b**2))
print(hipotenusa2)

# %% [markdown]
# **Con una función** (código limpio y reutilizable):

# %%
import math

def calcular_hipotenusa(cateto1a, cateto1b):
  hipotenusa = math.sqrt((cateto1a**2) + (cateto1b**2))
  return hipotenusa

hipotenusa1 = calcular_hipotenusa(4,6)
hipotenusa2 = calcular_hipotenusa(2,3)

print(hipotenusa1)
print(hipotenusa2)
# Out:
# 7.211102550927978
# 3.605551275463989

# %% [markdown]
# ---
#
# ## 5. Beneficios de usar funciones
#
# ### 5.1 Modularización
#
# Dividir un programa grande en partes pequeñas y manejables.
#
# Es como construir con LEGO: piezas pequeñas que juntas forman algo grande.

# %%
# Programa SIN modularizar (todo junto, difícil de leer)

nombre = "Ana"
edad = 25
print(f"Bienvenido/a {nombre}")
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
print(f"Tienes {edad} años")

# %%
# Programa MODULARIZADO (cada función hace una cosa)

def mostrar_bienvenida(nombre):
    """Muestra mensaje de bienvenida"""
    print(f"Bienvenido/a {nombre}")

def verificar_mayoria_edad(edad):
    """Verifica si es mayor de edad"""
    if edad >= 18:
        print("Eres mayor de edad")
    else:
        print("Eres menor de edad")

def mostrar_edad(edad):
    """Muestra la edad"""
    print(f"Tienes {edad} años")

# Programa principal (muy legible)
nombre = "Ana"
edad = 25

mostrar_bienvenida(nombre)
verificar_mayoria_edad(edad)
mostrar_edad(edad)

# %% [markdown]
# ### 5.2 Reutilización
#
# Escribir el código **una sola vez** y usarlo **muchas veces**.
#
# ¡No repitas código! (Principio DRY: Don't Repeat Yourself)

# %%
# Función reutilizable para validar números

def leer_numero_valido(minimo, maximo):
    """Lee un número del usuario entre minimo y maximo"""
    numero = minimo - 1  # Valor inicial inválido
    while numero < minimo or numero > maximo:
        numero_str = input(f"Introduce un número entre {minimo} y {maximo}: ")
        numero = int(numero_str)
    print("Número válido")
    return numero

# %%
# Ahora puedo reutilizar la función para diferentes rangos
# edad = leer_numero_valido(0, 120)
# mes = leer_numero_valido(1, 12)
# nota = leer_numero_valido(0, 10)

# %% [markdown]
# ---
#
# ## 6. Funciones con y sin return
#
# ### Función que devuelve resultado

# %%
def sumar(a, b):
    """Suma dos números y devuelve el resultado"""
    return a + b

# Podemos guardar el resultado
resultado = sumar(5, 3)
print(f"La suma es: {resultado}")
# Out:
# La suma es: 8

# %% [markdown]
# ### Función que NO devuelve resultado (solo hace algo)

# %%
def mostrar_suma(a, b):
    """Muestra la suma de dos números (no devuelve nada)"""
    print(f"La suma de {a} + {b} = {a + b}")

# Solo muestra, no podemos guardar un resultado útil
mostrar_suma(5, 3)
# Out:
# La suma de 5 + 3 = 8

# %%
# ¿Qué pasa si intentamos guardar el resultado?
resultado = mostrar_suma(5, 3)
print(f"El resultado guardado es: {resultado}")
print(f"El tipo es: {type(resultado)}")
# Out:
# La suma de 5 + 3 = 8
# El resultado guardado es: None
# El tipo es: <class 'NoneType'>

# %% [markdown]
# ### ¿Qué pasa si no guardamos el resultado de una función?

# %%
# Si no guardamos el resultado... ¡se pierde!
sumar(2, 3)  # Calcula 5 pero no lo guardamos
print("El programa continúa pero perdimos el resultado...")
# Out:
# El programa continúa pero perdimos el resultado...

# %% [markdown]
# ---
#
# ## 7. Documentación de funciones (Docstrings)
#
# Es importante documentar qué hace cada función.
#
# El **docstring** es el texto entre comillas triples justo después de `def`.

# %%
def calcular_area_rectangulo(base, altura):
    """Calcula el área de un rectángulo.

    Args:
        base (float): La base del rectángulo
        altura (float): La altura del rectángulo

    Returns:
        float: El área del rectángulo
    """
    return base * altura

# %%
# Podemos ver la documentación con help()
help(calcular_area_rectangulo)
# Out:
# Help on function calcular_area_rectangulo in module __main__:
#
# calcular_area_rectangulo(base, altura)
#     Calcula el área de un rectángulo.
#
#     Args:
#         base (float): La base del rectángulo
#         altura (float): La altura del rectángulo
#
#     Returns:
#         float: El área del rectángulo

# %% [markdown]
# ---
#
# ## 8. Type hints (indicar tipos)
#
# Python permite indicar qué tipo de datos espera una función.
#
# No es obligatorio, pero ayuda a entender el código.

# %%
# Sin type hints
def dividir(a, b):
    return a / b

# Con type hints (más claro)
def dividir_tipado(a: float, b: float) -> float:
    """Divide dos números"""
    return a / b

# %%
# Ambas funcionan igual
print(dividir(10, 3))
print(dividir_tipado(10, 3))
# Out:
# 3.3333333333333335
# 3.3333333333333335
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3316854263.py in <cell line: 0>()
#       2 print(dividir(10, 3))
#       3 print(dividir_tipado(10, 3))
# ----> 4 print(dividir_tipado("a", 3))
#
# /tmp/ipython-input-1021917199.py in dividir_tipado(a, b)
#       6 def dividir_tipado(a: float, b: float) -> float:
#       7     """Divide dos números"""
# ----> 8     return a / b
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ---
#
# ## 9. Parámetros con valores por defecto
#
# Puedes dar valores "de fábrica" a los parámetros.
#
# Si no se pasan, usan el valor por defecto.

# %%
def saludar_formal(nombre, saludo="Hola"):
    """Saluda con un saludo personalizable"""
    return f"{saludo}, {nombre}!"

# Usando el valor por defecto
print(saludar_formal("María"))

# Cambiando el saludo
print(saludar_formal("María", "Buenos días"))
print(saludar_formal("María", "¿Qué tal"))
# Out:
# Hola, María!
# Buenos días, María!
# ¿Qué tal, María!

# %%
# Ejemplo más completo
def formatear_nombre(nombre: str, apellido1: str, apellido2: str = "", formato: int = 1) -> str:
    if formato == 1:
        return f"{nombre} {apellido1} {apellido2}".strip()
    elif formato == 2:
        return f"{apellido1} {apellido2}, {nombre}".strip()
    return nombre

# %%
# Diferentes formas de llamar a la función
print(formatear_nombre("Luis", "García", "López"))
print(formatear_nombre("Luis", "García", "López", 2))
print(formatear_nombre("James", "Smith"))  # Sin segundo apellido
# Out:
# Luis García López
# García López, Luis
# James Smith

# %%
def saludar_formal(nombre, appelido1 = "", saludo="Hola"):
    """Saluda con un saludo personalizable"""
    return f"{saludo}, {nombre} {appelido1}"
# Usando el valor por defecto
print(saludar_formal("María"))

# Cambiando el saludo
print(saludar_formal("Arancha", saludo = "Buenos días", appelido1 = "García"))
print(saludar_formal("María", "¿Qué tal"))
# Out:
# Hola, María
# Buenos días, Arancha García
# Hola, María ¿Qué tal

# %% [markdown]
# ### Argumentos con nombre (keyword arguments)
#
# Puedes especificar qué valor va a qué parámetro usando su nombre.

# %%
# Llamada normal (por posición)
print(formatear_nombre("Luis", "García", "López", 2))

# Llamada con nombres (más clara)
print(formatear_nombre(nombre="Luis", apellido1="García", apellido2="López", formato=2))

# Útil cuando quieres saltar parámetros opcionales
print(formatear_nombre("James", "Smith", formato=2))  # Sin apellido2, pero con formato

# %% [markdown]
# ---
#
# ## 10. Devolver múltiples valores
#
# En Python, una función puede devolver varios valores a la vez (como una tupla).

# %%
def obtener_estadisticas(numeros):
    """Calcula varias estadísticas de una lista de números"""
    minimo = min(numeros)
    maximo = max(numeros)
    suma = sum(numeros)
    media = suma / len(numeros)
    return minimo, maximo, suma, media

# %%
# Recibir todos los valores
datos = [4, 8, 2, 9, 1, 7]
resultado = obtener_estadisticas(datos)
print(f"Resultado completo: {resultado}")
print(f"Tipo: {type(resultado)}")

minimo = resultado[0]
print(minimo)
# Out:
# Resultado completo: (1, 9, 31, 5.166666666666667)
# Tipo: <class 'tuple'>
# 1

# %%
# Desempaquetar en variables separadas
minimo, maximo, suma, media = obtener_estadisticas(datos)
print(f"Mínimo: {minimo}")
print(f"Máximo: {maximo}")
print(f"Suma: {suma}")
print(f"Media: {media}")
# Out:
# Mínimo: 1
# Máximo: 9
# Suma: 31
# Media: 5.166666666666667

# %%
datos = ["Arancha", "Carpintero"]
nombre, apellido = datos
print(nombre)
print(datos[0])
# Out:
# Arancha
# Arancha

# %% [markdown]
# ---
#
# ## 11. Ámbito de variables (scope)
#
# Las variables creadas **dentro** de una función solo existen **dentro** de ella.
#
# Esto se llama **ámbito local**.

# %%
def mi_funcion():
    pi = 3.14  # Solo existe dentro de la función
    print(f"Dentro de la función: {pi}")

mi_funcion()
# print(pi)

# Esto daría error porque variable_local no existe fuera
# print(variable_local)  # NameError!
# Out:
# Dentro de la función: 3.14

# %% [markdown]
# ### Variables globales vs locales

# %%
variable_global = 10  # Existe en todo el programa

def mi_funcion():
    variable_local = 25
    print(f"Variable local: {variable_local}")
    print(f"Variable global (accesible): {variable_global}")

mi_funcion()
print(f"Variable global fuera: {variable_global}")

# %%
# ¡Cuidado! Si creas una variable con el mismo nombre, es LOCAL
contador = 10

def incrementar():
    contador = 25  # Esto es una NUEVA variable local, no modifica la global
    return 25
    print(f"Dentro: {contador}")

contador = incrementar()
print(f"Fuera: {contador}")  # Sigue siendo 10
# Out:
# Fuera: 25

# %% [markdown]
# ### La palabra clave `global`
#
# Si necesitas modificar una variable global desde dentro de una función, usa `global`.
#
# ⚠️ **Pero evítalo si puedes** - es mejor pasar valores como parámetros y devolverlos.

# %%
contador = 10

def incrementar_global():
    global contador  # Indica que queremos usar la global
    contador = 25
    print(f"Dentro: {contador}")

incrementar_global()
print(f"Fuera: {contador}")  # Ahora sí cambió

# %% [markdown]
# ---
#
# ## 12. Paso por valor vs paso por referencia
#
# ### Tipos básicos (int, float, str, bool) → Se pasan por VALOR (copia)

# %%
def duplicar(numero):
    numero = numero * 2
    print(f"Dentro de la función: {numero}")

mi_numero = 5
duplicar(mi_numero)
print(f"Fuera de la función: {mi_numero}")  # No cambió!

# %% [markdown]
# ### Tipos complejos (list, dict) → Se pasan por REFERENCIA

# %%
def agregar_elemento(lista):
    lista.append(99)
    print(f"Dentro de la función: {lista}")

mi_lista = [1, 2, 3]
agregar_elemento(mi_lista)
print(f"Fuera de la función: {mi_lista}")  # ¡SÍ cambió!

# %% [markdown]
# ---
#
# ## 13. Estructura de un programa con funciones
#
# El patrón recomendado es:
#
# 1. Imports
# 2. Definición de funciones
# 3. Programa principal

# %%
# 1. IMPORTS
import math

# 2. DEFINICIÓN DE FUNCIONES
def calcular_area_circulo(radio: float) -> float:
    """Calcula el área de un círculo dado su radio"""
    return math.pi * radio ** 2

def calcular_perimetro_circulo(radio: float) -> float:
    """Calcula el perímetro de un círculo dado su radio"""
    return 2 * math.pi * radio

def mostrar_resultados(radio: float, area: float, perimetro: float) -> None:
    """Muestra los resultados de forma formateada"""
    print(f"\nResultados para un círculo de radio {radio}:")
    print(f"  - Área: {area:.2f}")
    print(f"  - Perímetro: {perimetro:.2f}")

# 3. PROGRAMA PRINCIPAL
radio = 5
area = calcular_area_circulo(radio)
perimetro = calcular_perimetro_circulo(radio)
mostrar_resultados(radio, area, perimetro)

# %% [markdown]
# ---
#
# ## ✏️ Ejercicios para practicar
#
# ### Ejercicio 1: Función básica
# Crea una función `es_par(numero)` que devuelva `True` si el número es par, `False` si no.

# %%
# Tu código aquí
def es_par(numero):
    pass  # Reemplaza esto

# Pruebas
# print(es_par(4))   # True
# print(es_par(7))   # False
# print(es_par(0))   # True

# %% [markdown]
# ### Ejercicio 2: Función con varios parámetros
# Crea una función `calcular_precio_final(precio, descuento=0, iva=21)` que calcule el precio final aplicando descuento e IVA.

# %%
# Tu código aquí
def calcular_precio_final(precio, descuento=0, iva=21):
    pass  # Reemplaza esto

# Pruebas
# print(calcular_precio_final(100))              # 121.0
# print(calcular_precio_final(100, 10))          # 108.9
# print(calcular_precio_final(100, 10, 10))      # 99.0

# %% [markdown]
# ### Ejercicio 3: Función que devuelve múltiples valores
# Crea una función `analizar_texto(texto)` que devuelva: número de caracteres, número de palabras, número de vocales.

# %%
# Tu código aquí
def analizar_texto(texto):
    pass  # Reemplaza esto

# Prueba
# caracteres, palabras, vocales = analizar_texto("Hola mundo")
# print(f"Caracteres: {caracteres}, Palabras: {palabras}, Vocales: {vocales}")

# %% [markdown]
# ---
#
# ## 📝 Resumen
#
# | Concepto | Descripción |
# |----------|-------------|
# | `def` | Palabra clave para definir funciones |
# | Parámetros | "Ingredientes" que recibe la función |
# | `return` | Devuelve un resultado |
# | Docstring | Documentación de la función |
# | Type hints | Indicar tipos (opcional) |
# | Valores por defecto | `param=valor` |
# | Ámbito local | Variables solo existen dentro de la función |
# | `global` | Acceder a variable global (evitar si es posible) |
#
# ### Reglas de oro:
# 1. **Una función = una tarea** (principio de responsabilidad única)
# 2. **Nombres descriptivos** (verbos: calcular, obtener, mostrar...)
# 3. **Documenta** qué hace cada función
# 4. **Evita código repetido** - crea funciones reutilizables
# 5. **Evita variables globales** - pasa datos como parámetros
